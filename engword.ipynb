# %%
with open('collins.txt') as f:
    s=[i.split('\t') for i in f.readlines()]
s
# Out:
# [['Collins Scrabble Words (2019). 279,496 words with definitions.\n'],
#  ['\n'],
#  ['AA',
#   '(Hawaiian) a volcanic rock consisting of angular blocks of lava with a very rough surface [n -S]\n'],
#  ['AAH',
#   'an interjection expressing surprise [interj] / to exclaim in surprise [v -ED, -ING, -S]\n'],
#  ['AAHED', 'AAH, to exclaim in surprise [v]\n'],
#  ['AAHING', 'AAH, to exclaim in surprise [v]\n'],
#  ['AAHS', 'AAH, to exclaim in surprise [v]\n'],
#  ['AAL', '(Hindi) the Indian mulberry tree, aka noni, also AL [n -S]\n'],
#  ['AALII', '(Hawaiian) a tropical tree [n -S]\n'],
#  ['AALIIS', 'AALII, (Hawaiian) a tropical tree [n]\n'],
#  ['AALS', 'AAL, (Hindi) the Indian mulberry tree, aka noni, also AL [n]\n'],
#  ['AARDVARK',
#   '(South African) a nocturnal, insectivorous, badger-sized mammal native to sub-Saharan Africa [n -S]\n'],
#  ['AARDVARKS',
#   'AARDVARK, (South African) a nocturnal, insectivorous, badger-sized mammal native to sub-Saharan Africa [n]\n'],
# ...

# %%
s.sort(key=lambda x:len(x[0]))
s
# Out:
# [['\n'],
#  ['AA',
#   '(Hawaiian) a volcanic rock consisting of angular blocks of lava with a very rough surface [n -S]\n'],
#  ['AB', 'an abdominal muscle [n -S]\n'],
#  ['AD', '(colloquial) an advertisement [n -S]\n'],
#  ['AE', '(Scots) one, also YAE [adj]\n'],
#  ['AG', '(short for) agriculture [n -S]\n'],
#  ['AH',
#   'an interjection expressing surprise, joy etc. [interj] / to say ah [v -ED, -ING, -S]\n'],
#  ['AI', '(Tupi) a three-toed sloth [n -S]\n'],
#  ['AL', '(Hindi) the Indian mulberry tree, aka noni, also AAL [n -S]\n'],
#  ['AM', 'BE, to exist [v]\n'],
#  ['AN',
#   'the indefinite article [adj] / a dialect form of if, an additional consideration, as in ifs and ans [n -S]\n'],
#  ['AR', 'the letter R [n -S]\n'],
#  ['AS',
#   'a Norse god living in Asgard [n AESIR] / a gravel ridge or kame [n ASAR] / a Roman coin [n ASSES]\n'],
#  ['AT', 'a monetary unit of Laos [n -S]\n'],
#  ['AW', 'an interjection used to express disgust, sympathy [interj]\n'],
# ...

# %%
s[:200]
# Out:
# [['\n'],
#  ['AA',
#   '(Hawaiian) a volcanic rock consisting of angular blocks of lava with a very rough surface [n -S]\n'],
#  ['AB', 'an abdominal muscle [n -S]\n'],
#  ['AD', '(colloquial) an advertisement [n -S]\n'],
#  ['AE', '(Scots) one, also YAE [adj]\n'],
#  ['AG', '(short for) agriculture [n -S]\n'],
#  ['AH',
#   'an interjection expressing surprise, joy etc. [interj] / to say ah [v -ED, -ING, -S]\n'],
#  ['AI', '(Tupi) a three-toed sloth [n -S]\n'],
#  ['AL', '(Hindi) the Indian mulberry tree, aka noni, also AAL [n -S]\n'],
#  ['AM', 'BE, to exist [v]\n'],
#  ['AN',
#   'the indefinite article [adj] / a dialect form of if, an additional consideration, as in ifs and ans [n -S]\n'],
#  ['AR', 'the letter R [n -S]\n'],
#  ['AS',
#   'a Norse god living in Asgard [n AESIR] / a gravel ridge or kame [n ASAR] / a Roman coin [n ASSES]\n'],
#  ['AT', 'a monetary unit of Laos [n -S]\n'],
#  ['AW', 'an interjection used to express disgust, sympathy [interj]\n'],
# ...
